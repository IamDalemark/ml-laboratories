# %% [markdown]
# # Midterm Practical
#
# General Instructions: For this exam, use dataset `abalone.csv` in an ML project. Good luck! Remember: You are not allowed to connect to the Internet. You can open all past codes
#
# ## Task:
#
# - Predict `rings` (use regression)
#
# ## Requirements:
#
# - Exploratory Data Analysis (descriptive statistics, visualization, correlation)
# - Data cleaning (if needed)
# - Train a baseline Model
# - Train and test split
# - Through the use of markdown cells, narrate/label each portion of your notebook as you go through the ML project.
#
# ## Breakdown of Score:
#
# - 60% = Requirements Fulfilled (did you manage to do everything required?)
# - 40% = Analysis (were you able to explain your results? your visualizations? when you made decisions, did you explain them?)
#
# ## Dataset Information:
#
# Predicting the age of abalone from physical measurements.  The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task.  Other measurements, which are easier to obtain, are used to predict the age.  Further information, such as weather patterns and location (hence food availability) may be required to solve the problem.
#
# From the original data examples with missing values were removed (the majority having the predicted value missing), and the ranges of the continuous values have been scaled for use with an ANN (by dividing by 200).
#
# ## Column Information:
#
# Given is the attribute name, attribute type, the measurement unit and a brief description.  The number of rings is the value to predict: either as a continuous value or as a classification problem.
#
# | Name | Data Type | Measurement Unit | Description |
# | ---- | --------- | ---------------- | ----------- |
# | Sex  | nominal   | -- | M, F, and I (infant) |
# | Length | continuous | mm | Longest shell measurement
# | Diameter	| continuous | mm | perpendicular to length
# | Height | continuous | mm | with meat in shell
# | Whole weight | continuous | grams | whole abalone
# | Shucked weight | continuous	 | grams | weight of meat
# | Viscera weight | continuous | grams | gut weight (after bleeding)
# | Shell weight | continuous | grams | after being dried
# | Rings | integer | -- | +1.5 gives the age in years
#
# ## Deliverables:
#
# - This
#
# ## Submission link (only submit this file): [Dropbox](https://www.dropbox.com/request/hsruiF7gCdFh2x2cBviT)
